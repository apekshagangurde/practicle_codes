# %% [markdown]
# # <font>2.Interact with the OpenWeatherMap API using the API key to retrieve weather data for a specific location</font>

# %%
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://api.openweathermap.org/data/2.5/forecast?lat=44.34&lon=10.99&appid=42c0ec72ba88838a86ba63' # <-- This is app id also known as api key, which you have to generate your own, and paste it here

#vurl ='https://api.openweathermap.org/data/2.5/weather?lat=44.34&lon=10.99&appid=307d11bca480dd730d99187c926&city_name=London'
response = requests.get(url)
data = response.json()
pretty_json = json.dumps(data,indent=4)
print(pretty_json)
# Out:
# {
#     "cod": "200",
#     "message": 0,
#     "cnt": 40,
#     "list": [
#         {
#             "dt": 1730624400,
#             "main": {
#                 "temp": 283.93,
#                 "feels_like": 283.23,
#                 "temp_min": 283.93,
#                 "temp_max": 286.12,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 959,
#                 "humidity": 83,
#                 "temp_kf": -2.19
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 95
#             },
#             "wind": {
#                 "speed": 1.23,
#                 "deg": 15,
#                 "gust": 1.41
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-03 09:00:00"
#         },
#         {
#             "dt": 1730635200,
#             "main": {
#                 "temp": 286.35,
#                 "feels_like": 285.74,
#                 "temp_min": 286.35,
#                 "temp_max": 288.11,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 959,
#                 "humidity": 77,
#                 "temp_kf": -1.76
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 92
#             },
#             "wind": {
#                 "speed": 2.38,
#                 "deg": 36,
#                 "gust": 2.5
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-03 12:00:00"
#         },
#         {
#             "dt": 1730646000,
#             "main": {
#                 "temp": 286.7,
#                 "feels_like": 286.28,
#                 "temp_min": 286.7,
#                 "temp_max": 286.7,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 958,
#                 "humidity": 83,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "clouds": {
#                 "all": 11
#             },
#             "wind": {
#                 "speed": 1.35,
#                 "deg": 37,
#                 "gust": 1.79
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-03 15:00:00"
#         },
#         {
#             "dt": 1730656800,
#             "main": {
#                 "temp": 282.98,
#                 "feels_like": 282.67,
#                 "temp_min": 282.98,
#                 "temp_max": 282.98,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 958,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 10
#             },
#             "wind": {
#                 "speed": 1.44,
#                 "deg": 219,
#                 "gust": 0.65
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-03 18:00:00"
#         },
#         {
#             "dt": 1730667600,
#             "main": {
#                 "temp": 282.37,
#                 "feels_like": 281.9,
#                 "temp_min": 282.37,
#                 "temp_max": 282.37,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 959,
#                 "humidity": 90,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 9
#             },
#             "wind": {
#                 "speed": 1.51,
#                 "deg": 224,
#                 "gust": 0.67
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-03 21:00:00"
#         },
#         {
#             "dt": 1730678400,
#             "main": {
#                 "temp": 282.04,
#                 "feels_like": 281.41,
#                 "temp_min": 282.04,
#                 "temp_max": 282.04,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 959,
#                 "humidity": 90,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 6
#             },
#             "wind": {
#                 "speed": 1.62,
#                 "deg": 228,
#                 "gust": 0.84
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-04 00:00:00"
#         },
#         {
#             "dt": 1730689200,
#             "main": {
#                 "temp": 281.83,
#                 "feels_like": 281.32,
#                 "temp_min": 281.83,
#                 "temp_max": 281.83,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 958,
#                 "humidity": 89,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 1.48,
#                 "deg": 227,
#                 "gust": 0.85
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-04 03:00:00"
#         },
#         {
#             "dt": 1730700000,
#             "main": {
#                 "temp": 281.63,
#                 "feels_like": 281.03,
#                 "temp_min": 281.63,
#                 "temp_max": 281.63,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 958,
#                 "humidity": 86,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 1.53,
#                 "deg": 227,
#                 "gust": 0.96
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-04 06:00:00"
#         },
#         {
#             "dt": 1730710800,
#             "main": {
#                 "temp": 287.04,
#                 "feels_like": 286.29,
#                 "temp_min": 287.04,
#                 "temp_max": 287.04,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 958,
#                 "humidity": 69,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 1
#             },
#             "wind": {
#                 "speed": 0.93,
#                 "deg": 32,
#                 "gust": 0.65
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-04 09:00:00"
#         },
#         {
#             "dt": 1730721600,
#             "main": {
#                 "temp": 289.3,
#                 "feels_like": 288.64,
#                 "temp_min": 289.3,
#                 "temp_max": 289.3,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 957,
#                 "humidity": 64,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 1
#             },
#             "wind": {
#                 "speed": 1.96,
#                 "deg": 37,
#                 "gust": 0.87
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-04 12:00:00"
#         },
#         {
#             "dt": 1730732400,
#             "main": {
#                 "temp": 287.28,
#                 "feels_like": 286.89,
#                 "temp_min": 287.28,
#                 "temp_max": 287.28,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 957,
#                 "humidity": 82,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 1.57,
#                 "deg": 47,
#                 "gust": 1.48
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-04 15:00:00"
#         },
#         {
#             "dt": 1730743200,
#             "main": {
#                 "temp": 283.71,
#                 "feels_like": 283.2,
#                 "temp_min": 283.71,
#                 "temp_max": 283.71,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 957,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 1.54,
#                 "deg": 218,
#                 "gust": 0.97
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-04 18:00:00"
#         },
#         {
#             "dt": 1730754000,
#             "main": {
#                 "temp": 283.25,
#                 "feels_like": 282.67,
#                 "temp_min": 283.25,
#                 "temp_max": 283.25,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 957,
#                 "humidity": 90,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 1.45,
#                 "deg": 218,
#                 "gust": 0.99
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-04 21:00:00"
#         },
#         {
#             "dt": 1730764800,
#             "main": {
#                 "temp": 282.68,
#                 "feels_like": 282.32,
#                 "temp_min": 282.68,
#                 "temp_max": 282.68,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 957,
#                 "humidity": 88,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 1.45,
#                 "deg": 226,
#                 "gust": 1.01
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-05 00:00:00"
#         },
#         {
#             "dt": 1730775600,
#             "main": {
#                 "temp": 282.42,
#                 "feels_like": 282.1,
#                 "temp_min": 282.42,
#                 "temp_max": 282.42,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 956,
#                 "humidity": 85,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 61
#             },
#             "wind": {
#                 "speed": 1.38,
#                 "deg": 229,
#                 "gust": 0.93
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-05 03:00:00"
#         },
#         {
#             "dt": 1730786400,
#             "main": {
#                 "temp": 282.19,
#                 "feels_like": 282.19,
#                 "temp_min": 282.19,
#                 "temp_max": 282.19,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 956,
#                 "humidity": 82,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 80
#             },
#             "wind": {
#                 "speed": 1.29,
#                 "deg": 224,
#                 "gust": 0.87
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-05 06:00:00"
#         },
#         {
#             "dt": 1730797200,
#             "main": {
#                 "temp": 286.42,
#                 "feels_like": 285.6,
#                 "temp_min": 286.42,
#                 "temp_max": 286.42,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 957,
#                 "humidity": 69,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 0.83,
#                 "deg": 23,
#                 "gust": 0.42
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-05 09:00:00"
#         },
#         {
#             "dt": 1730808000,
#             "main": {
#                 "temp": 289.11,
#                 "feels_like": 288.35,
#                 "temp_min": 289.11,
#                 "temp_max": 289.11,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "grnd_level": 956,
#                 "humidity": 61,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 65
#             },
#             "wind": {
#                 "speed": 1.89,
#                 "deg": 38,
#                 "gust": 0.75
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-05 12:00:00"
#         },
#         {
#             "dt": 1730818800,
#             "main": {
#                 "temp": 286.93,
#                 "feels_like": 286.48,
#                 "temp_min": 286.93,
#                 "temp_max": 286.93,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "grnd_level": 956,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 1.67,
#                 "deg": 43,
#                 "gust": 1.53
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-05 15:00:00"
#         },
#         {
#             "dt": 1730829600,
#             "main": {
#                 "temp": 283.33,
#                 "feels_like": 282.81,
#                 "temp_min": 283.33,
#                 "temp_max": 283.33,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 956,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 6
#             },
#             "wind": {
#                 "speed": 1.51,
#                 "deg": 216,
#                 "gust": 1.02
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-05 18:00:00"
#         },
#         {
#             "dt": 1730840400,
#             "main": {
#                 "temp": 283.16,
#                 "feels_like": 282.59,
#                 "temp_min": 283.16,
#                 "temp_max": 283.16,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 956,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 71
#             },
#             "wind": {
#                 "speed": 1.04,
#                 "deg": 231,
#                 "gust": 0.5
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-05 21:00:00"
#         },
#         {
#             "dt": 1730851200,
#             "main": {
#                 "temp": 282.79,
#                 "feels_like": 282.79,
#                 "temp_min": 282.79,
#                 "temp_max": 282.79,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 957,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 85
#             },
#             "wind": {
#                 "speed": 1.06,
#                 "deg": 239,
#                 "gust": 0.53
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 00:00:00"
#         },
#         {
#             "dt": 1730862000,
#             "main": {
#                 "temp": 282.52,
#                 "feels_like": 282.52,
#                 "temp_min": 282.52,
#                 "temp_max": 282.52,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 957,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 0.84,
#                 "deg": 242,
#                 "gust": 0.36
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 03:00:00"
#         },
#         {
#             "dt": 1730872800,
#             "main": {
#                 "temp": 282.17,
#                 "feels_like": 282.17,
#                 "temp_min": 282.17,
#                 "temp_max": 282.17,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 957,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 0.73,
#                 "deg": 239,
#                 "gust": 0.28
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 06:00:00"
#         },
#         {
#             "dt": 1730883600,
#             "main": {
#                 "temp": 285.38,
#                 "feels_like": 284.7,
#                 "temp_min": 285.38,
#                 "temp_max": 285.38,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 959,
#                 "humidity": 78,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 1.27,
#                 "deg": 8,
#                 "gust": 1.26
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-06 09:00:00"
#         },
#         {
#             "dt": 1730894400,
#             "main": {
#                 "temp": 286.74,
#                 "feels_like": 286.06,
#                 "temp_min": 286.74,
#                 "temp_max": 286.74,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 958,
#                 "humidity": 73,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 1.89,
#                 "deg": 28,
#                 "gust": 1.6
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-06 12:00:00"
#         },
#         {
#             "dt": 1730905200,
#             "main": {
#                 "temp": 285.14,
#                 "feels_like": 284.59,
#                 "temp_min": 285.14,
#                 "temp_max": 285.14,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 959,
#                 "humidity": 84,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 1.35,
#                 "deg": 39,
#                 "gust": 1.87
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-06 15:00:00"
#         },
#         {
#             "dt": 1730916000,
#             "main": {
#                 "temp": 282.97,
#                 "feels_like": 282.97,
#                 "temp_min": 282.97,
#                 "temp_max": 282.97,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 959,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 0.29,
#                 "deg": 262,
#                 "gust": 0.19
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 18:00:00"
#         },
#         {
#             "dt": 1730926800,
#             "main": {
#                 "temp": 282.24,
#                 "feels_like": 282.24,
#                 "temp_min": 282.24,
#                 "temp_max": 282.24,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 90,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 0.64,
#                 "deg": 233,
#                 "gust": 0.22
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 21:00:00"
#         },
#         {
#             "dt": 1730937600,
#             "main": {
#                 "temp": 281.22,
#                 "feels_like": 281.22,
#                 "temp_min": 281.22,
#                 "temp_max": 281.22,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 0.93,
#                 "deg": 254,
#                 "gust": 0.31
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 00:00:00"
#         },
#         {
#             "dt": 1730948400,
#             "main": {
#                 "temp": 280.89,
#                 "feels_like": 280.89,
#                 "temp_min": 280.89,
#                 "temp_max": 280.89,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 95,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 98
#             },
#             "wind": {
#                 "speed": 1,
#                 "deg": 248,
#                 "gust": 0.31
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 03:00:00"
#         },
#         {
#             "dt": 1730959200,
#             "main": {
#                 "temp": 280.43,
#                 "feels_like": 280.43,
#                 "temp_min": 280.43,
#                 "temp_max": 280.43,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 96,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 96
#             },
#             "wind": {
#                 "speed": 1.06,
#                 "deg": 255,
#                 "gust": 0.48
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 06:00:00"
#         },
#         {
#             "dt": 1730970000,
#             "main": {
#                 "temp": 284.28,
#                 "feels_like": 283.67,
#                 "temp_min": 284.28,
#                 "temp_max": 284.28,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 961,
#                 "humidity": 85,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 70
#             },
#             "wind": {
#                 "speed": 1.29,
#                 "deg": 24,
#                 "gust": 1.06
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-07 09:00:00"
#         },
#         {
#             "dt": 1730980800,
#             "main": {
#                 "temp": 285,
#                 "feels_like": 284.36,
#                 "temp_min": 285,
#                 "temp_max": 285,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 83
#             },
#             "wind": {
#                 "speed": 1.76,
#                 "deg": 39,
#                 "gust": 1.35
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-07 12:00:00"
#         },
#         {
#             "dt": 1730991600,
#             "main": {
#                 "temp": 283.93,
#                 "feels_like": 283.47,
#                 "temp_min": 283.93,
#                 "temp_max": 283.93,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 0.61,
#                 "deg": 89,
#                 "gust": 0.95
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-07 15:00:00"
#         },
#         {
#             "dt": 1731002400,
#             "main": {
#                 "temp": 283.73,
#                 "feels_like": 283.25,
#                 "temp_min": 283.73,
#                 "temp_max": 283.73,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 961,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 0.18,
#                 "deg": 273,
#                 "gust": 0
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 18:00:00"
#         },
#         {
#             "dt": 1731013200,
#             "main": {
#                 "temp": 283.05,
#                 "feels_like": 283.05,
#                 "temp_min": 283.05,
#                 "temp_max": 283.05,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 961,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 96
#             },
#             "wind": {
#                 "speed": 0.52,
#                 "deg": 274,
#                 "gust": 0.02
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 21:00:00"
#         },
#         {
#             "dt": 1731024000,
#             "main": {
#                 "temp": 283.02,
#                 "feels_like": 283.02,
#                 "temp_min": 283.02,
#                 "temp_max": 283.02,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 961,
#                 "humidity": 95,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 96
#             },
#             "wind": {
#                 "speed": 0.38,
#                 "deg": 310,
#                 "gust": 0.2
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 00:00:00"
#         },
#         {
#             "dt": 1731034800,
#             "main": {
#                 "temp": 282.84,
#                 "feels_like": 282.84,
#                 "temp_min": 282.84,
#                 "temp_max": 282.84,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 961,
#                 "humidity": 97,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 95
#             },
#             "wind": {
#                 "speed": 0.2,
#                 "deg": 342,
#                 "gust": 0.46
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 03:00:00"
#         },
#         {
#             "dt": 1731045600,
#             "main": {
#                 "temp": 283.15,
#                 "feels_like": 283.15,
#                 "temp_min": 283.15,
#                 "temp_max": 283.15,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 961,
#                 "humidity": 97,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 98
#             },
#             "wind": {
#                 "speed": 0.7,
#                 "deg": 332,
#                 "gust": 1.26
#             },
#             "visibility": 6814,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 06:00:00"
#         }
#     ],
#     "city": {
#         "id": 3163858,
#         "name": "Zocca",
#         "coord": {
#             "lat": 44.34,
#             "lon": 10.99
#         },
#         "country": "IT",
#         "population": 4593,
#         "timezone": 3600,
#         "sunrise": 1730613366,
#         "sunset": 1730649781
#     }
# }

# %%
date_time = data['list'][0]['dt_txt']
date_time
# Out:
# '2024-10-31 12:00:00'

# %% [markdown]
# # 3.Extract relevant weather attributes such as temperature, humidity, wind speed, and  precipitation from the API response

# %%
data_struct = []
for record in data['list']:
    temp = record['main']['temp']
    humid = record['main']['humidity']
    wind_speed = record['wind']['speed']
    desp =record['weather'][0]['description']
    date_time = record['dt_txt']

    data_struct.append({'Temperature':temp,'Humidity':humid,'Wind Speed':wind_speed,'Weather Description':desp,'Date Time':date_time})

data_df = pd.DataFrame(data_struct)
data_df[['Date','Time']] = data_df['Date Time'].str.split(' ',expand=True)
data_df.head(10)
# Out:
#    Temperature  Humidity  Wind Speed Weather Description            Date Time  \
# 0       280.16        88        1.23     overcast clouds  2024-11-03 09:00:00
# 1       284.47        79        2.38     overcast clouds  2024-11-03 12:00:00
# 2       286.70        83        1.35          few clouds  2024-11-03 15:00:00
# 3       282.98        92        1.44           clear sky  2024-11-03 18:00:00
# 4       282.37        90        1.51           clear sky  2024-11-03 21:00:00
# 5       282.04        90        1.62           clear sky  2024-11-04 00:00:00
# 6       281.83        89        1.48           clear sky  2024-11-04 03:00:00
# 7       281.63        86        1.53           clear sky  2024-11-04 06:00:00
# 8       287.04        69        0.93           clear sky  2024-11-04 09:00:00
# 9       289.30        64        1.96           clear sky  2024-11-04 12:00:00
#
#          Date      Time
# 0  2024-11-03  09:00:00
# 1  2024-11-03  12:00:00
# 2  2024-11-03  15:00:00
# 3  2024-11-03  18:00:00
# 4  2024-11-03  21:00:00
# 5  2024-11-04  00:00:00
# 6  2024-11-04  03:00:00
# 7  2024-11-04  06:00:00
# 8  2024-11-04  09:00:00
# 9  2024-11-04  12:00:00

# %%
data_df.shape
# Out:
# (40, 7)

# %% [markdown]
# # 4.Clean and preprocess the retrieved data, handling missing values or inconsistent  formats.

# %%
data_df.isnull().sum()
# Out:
# Temperature            0
# Humidity               0
# Wind Speed             0
# Weather Description    0
# Date Time              0
# Date                   0
# Time                   0
# dtype: int64

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Temperature          40 non-null     float64
#  1   Humidity             40 non-null     int64
#  2   Wind Speed           40 non-null     float64
#  3   Weather Description  40 non-null     object
#  4   Date Time            40 non-null     object
#  5   Date                 40 non-null     object
#  6   Time                 40 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.3+ KB

# %% [markdown]
# # 5.Perform data modeling to analyze weather patterns, such as calculating average temperature, maximum/minimum values, or trends over time.

# %%
data_df.describe()
# Out:
#        Temperature   Humidity  Wind Speed
# count    40.000000  40.000000   40.000000
# mean    282.972250  77.100000    1.241250
# std       3.028698  12.421652    0.555902
# min     278.180000  51.000000    0.190000
# 25%     280.550000  69.500000    0.857500
# 50%     282.590000  81.500000    1.135000
# 75%     284.550000  86.250000    1.662500
# max     289.890000  93.000000    2.370000

# %% [markdown]
# # <font>6.Visualize the weather data using appropriate plots, such as line charts, bar plots, or scatter plots, to represent temperature changes, precipitation levels, or wind speed variations.</font>

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10,5))
sns.scatterplot(x=data_df['Date Time'],
                y=data_df['Temperature'],
                hue=data_df['Weather Description'])

plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,5))
plt.plot(data_df['Date Time'],data_df['Humidity'])
plt.xticks(rotation=90);

# %% [markdown]
# # <font>7.Apply data aggregation techniques to summarize weather statistics by specific time periods</font>

# %%
data_df.groupby('Date').agg({'Temperature' : 'mean','Wind Speed':'mean'})
# Out:
#             Temperature  Wind Speed
# Date
# 2024-11-03   283.336000    1.582000
# 2024-11-04   284.510000    1.510000
# 2024-11-05   284.530000    1.382500
# 2024-11-06   283.743750    1.008750
# 2024-11-07   282.703750    0.983750
# 2024-11-08   283.213333    0.663333

# %% [markdown]
# # <font>9.Explore and visualize relationships between weather attributes, such as temperature and humidity, using correlation plots or heatmaps.</font>

# %%
sns.heatmap(data_df[['Temperature','Humidity','Wind Speed']].corr(),annot=True,cmap='crest')
# Out:
# <Axes: >
